# %%
import os
import json
import pandas as pd
import psycopg2

# %%
path_1="C:\\Users\\USER PC\\OneDrive\\Desktop\\Projects\\phonepe\\pulse-master\\data\\aggregated\\insurance\\country\\india\\state\\"

# %%
aggre_insur_list = os.listdir(path_1)

column1={"States":[], "Years":[], "Quarter":[], "Transaction_Type":[], "Transaction_Count":[], "Transaction_Amount":[]}
for state in aggre_insur_list:
    current_states=path_1+state+"\\"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list:
        current_year=current_states+year+"\\"
        agg_year_data=os.listdir(current_year)
        
        
        for file in agg_year_data:
            current_data=current_year+file
            data=open(current_data,"r")
            
            
            A=json.load(data)
            
            
            for i in A["data"]["transactionData"]:
                name=i["name"]
                insurance_count=i["paymentInstruments"][0]["count"]
                insurance_amount=i['paymentInstruments'][0]['amount']
                column1["Transaction_Type"].append(name)
                column1["Transaction_Count"].append(insurance_count)
                column1["Transaction_Amount"].append(insurance_amount)
                column1["States"].append(state)
                column1["Years"].append(year)
                column1["Quarter"].append(int(file.strip(".json")))

# %%
aggre_insurance = pd.DataFrame(column1)

aggre_insurance["States"]=aggre_insurance["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar Island')
aggre_insurance["States"]=aggre_insurance["States"].str.replace('-',' ')
aggre_insurance["States"]=aggre_insurance["States"].str.title()
aggre_insurance["States"]=aggre_insurance["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu ')

# %%
aggre_insurance["States"].unique()
# Out:
# array(['Andaman & Nicobar Island', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu ', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
aggre_insurance
# Out:
#                        States Years  Quarter Transaction_Type  \
# 0    Andaman & Nicobar Island  2020        2        Insurance
# 1    Andaman & Nicobar Island  2020        3        Insurance
# 2    Andaman & Nicobar Island  2020        4        Insurance
# 3    Andaman & Nicobar Island  2021        1        Insurance
# 4    Andaman & Nicobar Island  2021        2        Insurance
# ..                        ...   ...      ...              ...
# 497               West Bengal  2022        3        Insurance
# 498               West Bengal  2022        4        Insurance
# 499               West Bengal  2023        1        Insurance
# 500               West Bengal  2023        2        Insurance
# 501               West Bengal  2023        3        Insurance
#
#      Transaction_Count  Transaction_Amount
# 0                    6              1360.0
# 1                   41             15380.0
# 2                  124            157975.0
# 3                  225            244266.0
# ...

# %%
path_2="C:\\Users\\USER PC\\OneDrive\\Desktop\\Projects\\phonepe\\pulse-master\\data\\aggregated\\transaction\\country\\india\\state\\"

# %%
aggre_trans_list = os.listdir(path_2)

column2={"States":[], "Years":[], "Quarter":[], "Transaction_Type":[], "Transaction_Count":[], "Transaction_Amount":[]}
for state in aggre_trans_list:
    current_states=path_2+state+"\\"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list:
        current_year=current_states+year+"\\"
        agg_year_data=os.listdir(current_year)
        
        
        for file in agg_year_data:
            current_data=current_year+file
            data=open(current_data,"r")
            
            
            B=json.load(data)
            
            
            for i in B["data"]["transactionData"]:
                name=i["name"]
                transaction_count=i["paymentInstruments"][0]["count"]
                transaction_amount=i['paymentInstruments'][0]['amount']
                column2["Transaction_Type"].append(name)
                column2["Transaction_Count"].append(transaction_count)
                column2["Transaction_Amount"].append(transaction_amount)
                column2["States"].append(state)
                column2["Years"].append(year)
                column2["Quarter"].append(int(file.strip(".json")))

# %%
aggre_transaction=pd.DataFrame(column2)

aggre_transaction["States"]=aggre_transaction["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar Island')
aggre_transaction["States"]=aggre_transaction["States"].str.replace('-',' ')
aggre_transaction["States"]=aggre_transaction["States"].str.title()
aggre_transaction["States"]=aggre_transaction["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu ')

# %%
aggre_transaction["States"].unique()
# Out:
# array(['Andaman & Nicobar Island', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu ', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
aggre_transaction
# Out:
#                         States Years  Quarter          Transaction_Type  \
# 0     Andaman & Nicobar Island  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar Island  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar Island  2018        1         Merchant payments
# 3     Andaman & Nicobar Island  2018        1        Financial Services
# 4     Andaman & Nicobar Island  2018        1                    Others
# ...                        ...   ...      ...                       ...
# 4129               West Bengal  2023        3         Merchant payments
# 4130               West Bengal  2023        3     Peer-to-peer payments
# 4131               West Bengal  2023        3  Recharge & bill payments
# 4132               West Bengal  2023        3        Financial Services
# 4133               West Bengal  2023        3                    Others
#
#       Transaction_Count  Transaction_Amount
# 0                  4200        1.845307e+06
# ...

# %%
path_3="C:\\Users\\USER PC\\OneDrive\\Desktop\\Projects\\phonepe\\pulse-master\\data\\aggregated\\user\\country\\india\\state\\"

# %%
column3={"States":[], "Years":[], "Quarter":[], "Brands":[], "Transaction_Count":[], "Percentage":[]}
aggre_user_list=os.listdir(path_3)
for state in aggre_user_list:
    current_states=path_3+state+"\\"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list:
        current_year=current_states+year+"\\"
        agg_year_data=os.listdir(current_year)
        
        
        for file in agg_year_data:
            current_data=current_year+file
            data=open(current_data,"r")
            
            
            C=json.load(data)
            
            try:
                    
                for i in C["data"]["usersByDevice"]:
                    brands=i["brand"]
                    users_count=i["count"]
                    users_percentage=i['percentage']
                    column3["Brands"].append(brands)
                    column3["Transaction_Count"].append(users_count)
                    column3["Percentage"].append(users_percentage)
                    column3["States"].append(state)
                    column3["Years"].append(year)
                    column3["Quarter"].append(int(file.strip(".json")))
            
            except:
                pass

# %%
agg_user=pd.DataFrame(column3)

agg_user["States"]=agg_user["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar Island')
agg_user["States"]=agg_user["States"].str.replace('-',' ')
agg_user["States"]=agg_user["States"].str.title()
agg_user["States"]=agg_user["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu ')

# %%
agg_user
# Out:
#                         States Years  Quarter   Brands  Transaction_Count  \
# 0     Andaman & Nicobar Island  2018        1   Xiaomi               1665
# 1     Andaman & Nicobar Island  2018        1  Samsung               1445
# 2     Andaman & Nicobar Island  2018        1     Vivo                982
# 3     Andaman & Nicobar Island  2018        1     Oppo                501
# 4     Andaman & Nicobar Island  2018        1  OnePlus                332
# ...                        ...   ...      ...      ...                ...
# 6727               West Bengal  2022        1   Lenovo             330017
# 6728               West Bengal  2022        1  Infinix             284678
# 6729               West Bengal  2022        1     Asus             280347
# 6730               West Bengal  2022        1    Apple             277752
# 6731               West Bengal  2022        1   Others            2196334
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
path_4="C:\\Users\\USER PC\\OneDrive\\Desktop\\Projects\\phonepe\\pulse-master\\data\\map\\insurance\\hover\\country\\india\\state\\"

# %%
column4={"States":[], "Years":[], "Quarter":[], "District_Name":[], "Transaction_Count":[], "Transaction_Amount":[]}
map_insur_list=os.listdir(path_4)

for state in map_insur_list:
    current_states=path_4+state+"\\"
    map_year_list=os.listdir(current_states)
    
    for year in map_year_list:
        current_year=current_states+year+"\\"
        map_year_data=os.listdir(current_year)
        
        
        for file in map_year_data:
            current_data=current_year+file
            data=open(current_data,"r")
            
            
            D=json.load(data)
            
            for i in D["data"]["hoverDataList"]:
                name=i["name"]
                count=i["metric"][0]["count"]
                amount=i["metric"][0]["amount"]
                column4["District_Name"].append(name)
                column4["Transaction_Count"].append(count)
                column4["Transaction_Amount"].append(amount)
                column4["States"].append(state)
                column4["Years"].append(year)
                column4["Quarter"].append(int(file.strip(".json")))

# %%
map_insurance=pd.DataFrame(column4)

map_insurance["States"]=map_insurance["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar Island')
map_insurance["States"]=map_insurance["States"].str.replace('-',' ')
map_insurance["States"]=map_insurance["States"].str.title()
map_insurance["States"]=map_insurance["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu ')

# %%
map_insurance
# Out:
#                          States Years  Quarter  \
# 0      Andaman & Nicobar Island  2020        2
# 1      Andaman & Nicobar Island  2020        2
# 2      Andaman & Nicobar Island  2020        3
# 3      Andaman & Nicobar Island  2020        3
# 4      Andaman & Nicobar Island  2020        3
# ...                         ...   ...      ...
# 10096               West Bengal  2023        3
# 10097               West Bengal  2023        3
# 10098               West Bengal  2023        3
# 10099               West Bengal  2023        3
# 10100               West Bengal  2023        3
#
#                            District_Name  Transaction_Count  \
# 0                 south andaman district                  3
# 1                      nicobars district                  3
# 2      north and middle andaman district                  1
# 3                 south andaman district                 35
# 4                      nicobars district                  5
# ...

# %%
path_5="C:\\Users\\USER PC\\OneDrive\\Desktop\\Projects\\phonepe\\pulse-master\\data\\map\\transaction\\hover\\country\\india\\state\\"

# %%
column5={"States":[], "Years":[], "Quarter":[], "District_Name":[], "Transaction_Count":[], "Transaction_Amount":[]}
map_transaction_list=os.listdir(path_5)

for state in map_transaction_list:
    current_states=path_5+state+"\\"
    map_year_list=os.listdir(current_states)
    
    for year in map_year_list:
        current_year=current_states+year+"\\"
        map_year_data=os.listdir(current_year)
        
        
        for file in map_year_data:
            current_data=current_year+file
            data=open(current_data,"r")
            
            
            E=json.load(data)
            
            for i in E["data"]["hoverDataList"]:
                    name=i["name"]
                    count=i["metric"][0]["count"]
                    amount=i["metric"][0]["amount"]
                    column5["District_Name"].append(name)
                    column5["Transaction_Count"].append(count)
                    column5["Transaction_Amount"].append(amount)
                    column5["States"].append(state)
                    column5["Years"].append(year)
                    column5["Quarter"].append(int(file.strip(".json")))

# %%
map_transaction=pd.DataFrame(column5)

map_transaction["States"]=map_transaction["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar Island')
map_transaction["States"]=map_transaction["States"].str.replace('-',' ')
map_transaction["States"]=map_transaction["States"].str.title()
map_transaction["States"]=map_transaction["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu ')

# %%
map_transaction
# Out:
#                          States Years  Quarter  \
# 0      Andaman & Nicobar Island  2018        1
# 1      Andaman & Nicobar Island  2018        1
# 2      Andaman & Nicobar Island  2018        1
# 3      Andaman & Nicobar Island  2018        2
# 4      Andaman & Nicobar Island  2018        2
# ...                         ...   ...      ...
# 16827               West Bengal  2023        3
# 16828               West Bengal  2023        3
# 16829               West Bengal  2023        3
# 16830               West Bengal  2023        3
# 16831               West Bengal  2023        3
#
#                            District_Name  Transaction_Count  \
# 0      north and middle andaman district                442
# 1                 south andaman district               5688
# 2                      nicobars district                528
# 3      north and middle andaman district                825
# 4                 south andaman district               9395
# ...

# %%
path_6="C:\\Users\\USER PC\\OneDrive\\Desktop\\Projects\\phonepe\\pulse-master\\data\\map\\user\\hover\\country\\india\\state\\"

# %%
column6={"States":[], "Years":[], "Quarter":[], "District_Name":[], "Registered_Users":[], "App_Opens":[]}
map_user_list=os.listdir(path_6)

for state in map_user_list:
    current_states=path_6+state+"\\"
    map_year_list=os.listdir(current_states)
    
    for year in map_year_list:
        current_year=current_states+year+"\\"
        map_year_data=os.listdir(current_year)
        
        
        for file in map_year_data:
            current_data=current_year+file
            data=open(current_data,"r")
            
            
            F=json.load(data)
            
            for i in F["data"]["hoverData"].items():
                district=i[0]
                registeredUsers=i[1]["registeredUsers"]
                appOpens=i[1]["appOpens"]
                column6["District_Name"].append(district)
                column6["Registered_Users"].append(registeredUsers)
                column6["App_Opens"].append(appOpens)
                column6["States"].append(state)
                column6["Years"].append(year)
                column6["Quarter"].append(int(file.strip(".json")))

# %%
map_user=pd.DataFrame(column6)

map_user["States"]=map_user["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar Island')
map_user["States"]=map_user["States"].str.replace('-',' ')
map_user["States"]=map_user["States"].str.title()
map_user["States"]=map_user["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')

# %%
map_user
# Out:
#                          States Years  Quarter  \
# 0      Andaman & Nicobar Island  2018        1
# 1      Andaman & Nicobar Island  2018        1
# 2      Andaman & Nicobar Island  2018        1
# 3      Andaman & Nicobar Island  2018        2
# 4      Andaman & Nicobar Island  2018        2
# ...                         ...   ...      ...
# 16831               West Bengal  2023        3
# 16832               West Bengal  2023        3
# 16833               West Bengal  2023        3
# 16834               West Bengal  2023        3
# 16835               West Bengal  2023        3
#
#                            District_Name  Registered_Users  App_Opens
# 0      north and middle andaman district               632          0
# 1                 south andaman district              5846          0
# 2                      nicobars district               262          0
# 3      north and middle andaman district               911          0
# ...

# %%
path_7="C:\\Users\\USER PC\\OneDrive\Desktop\\Projects\\phonepe\\pulse-master\\data\\top\\insurance\\country\\india\\state\\"

# %%
column7={"States":[], "Years":[], "Quarter":[], "Pincodes":[], "Transaction_Count":[], "Transaction_Amount":[]}
top_insur_list=os.listdir(path_7)

for state in top_insur_list:
    current_states=path_7+state+"\\"
    top_year_list=os.listdir(current_states)
    
    for year in top_year_list:
        current_year=current_states+year+"\\"
        top_year_data=os.listdir(current_year)
        
        
        for file in top_year_data:
            current_data=current_year+file
            data=open(current_data,"r")
            
            
            G=json.load(data)
            
            for i in G["data"]["pincodes"]:
                entityname=i["entityName"]
                count=i["metric"]["count"]
                amount=i["metric"]["amount"]
                column7["Pincodes"].append(entityname)
                column7["Transaction_Count"].append(count)
                column7["Transaction_Amount"].append(amount)
                column7["States"].append(state)
                column7["Years"].append(year)
                column7["Quarter"].append(int(file.strip(".json")))

# %%
top_insurance=pd.DataFrame(column7)

top_insurance["States"]=top_insurance["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar Island')
top_insurance["States"]=top_insurance["States"].str.replace('-',' ')
top_insurance["States"]=top_insurance["States"].str.title()
top_insurance["States"]=top_insurance["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu ')

# %%
top_insurance
# Out:
#                         States Years  Quarter Pincodes  Transaction_Count  \
# 0     Andaman & Nicobar Island  2020        2   744301                  3
# 1     Andaman & Nicobar Island  2020        2   744104                  2
# 2     Andaman & Nicobar Island  2020        2   744101                  1
# 3     Andaman & Nicobar Island  2020        3   744112                  9
# 4     Andaman & Nicobar Island  2020        3   744105                  7
# ...                        ...   ...      ...      ...                ...
# 4890               West Bengal  2023        3   732101                461
# 4891               West Bengal  2023        3   700059                457
# 4892               West Bengal  2023        3   700015                451
# 4893               West Bengal  2023        3   700135                447
# 4894               West Bengal  2023        3   700019                427
#
#       Transaction_Amount
# 0                  565.0
# 1                  513.0
# ...

# %%
path_8="C:\\Users\\USER PC\\OneDrive\\Desktop\\Projects\\phonepe\\pulse-master\\data\\top\\transaction\\country\\india\\state\\"

# %%
column8={"States":[], "Years":[], "Quarter":[], "Entity_Name":[], "Transaction_Count":[], "Transaction_Amount":[]}
top_transaction_list=os.listdir(path_8)

for state in top_transaction_list:
    current_states=path_8+state+"\\"
    top_year_list=os.listdir(current_states)
    
    for year in top_year_list:
        current_year=current_states+year+"\\"
        top_year_data=os.listdir(current_year)
        
        
        for file in top_year_data:
            current_data=current_year+file
            data=open(current_data,"r")
            
            
            H=json.load(data)
            
            for i in H["data"]["pincodes"]:
                    entityname=i["entityName"]
                    count=i["metric"]["count"]
                    amount=i["metric"]["amount"]
                    column8["Entity_Name"].append(entityname)
                    column8["Transaction_Count"].append(count)
                    column8["Transaction_Amount"].append(amount)
                    column8["States"].append(state)
                    column8["Years"].append(year)
                    column8["Quarter"].append(int(file.strip(".json")))

# %%
top_transaction=pd.DataFrame(column8)

top_transaction["States"]=top_transaction["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar Island')
top_transaction["States"]=top_transaction["States"].str.replace('-',' ')
top_transaction["States"]=top_transaction["States"].str.title()
top_transaction["States"]=top_transaction["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu ')

# %%
top_transaction
# Out:
#                         States Years  Quarter Entity_Name  Transaction_Count  \
# 0     Andaman & Nicobar Island  2018        1      744101               1622
# 1     Andaman & Nicobar Island  2018        1      744103               1223
# 2     Andaman & Nicobar Island  2018        1      744102                969
# 3     Andaman & Nicobar Island  2018        1      744105                685
# 4     Andaman & Nicobar Island  2018        1      744104                340
# ...                        ...   ...      ...         ...                ...
# 8205               West Bengal  2023        3      700001            3536928
# 8206               West Bengal  2023        3      721301            3464729
# 8207               West Bengal  2023        3      700039            3405551
# 8208               West Bengal  2023        3      732125            3347165
# 8209               West Bengal  2023        3      700015            3304464
#
#       Transaction_Amount
# ...

# %%
path_9="C:\\Users\\USER PC\\OneDrive\\Desktop\\Projects\\phonepe\\pulse-master\\data\\top\\user\\country\\india\\state\\"

# %%
column9={"States":[], "Years":[], "Quarter":[], "Pincodes":[], "Registered_Users":[]}
top_user_list=os.listdir(path_9)

for state in top_user_list:
    current_states=path_9+state+"\\"
    mto_year_list=os.listdir(current_states)
    
    for year in top_year_list:
        current_year=current_states+year+"\\"
        top_year_data=os.listdir(current_year)
        
        
        for file in top_year_data:
            current_data=current_year+file
            data=open(current_data,"r")
            
            
            I=json.load(data)
            
            for i in I["data"]["pincodes"]:
                    entityname=i["name"]
                    registeredusers=i["registeredUsers"]
                    column9["Pincodes"].append(entityname)
                    column9["Registered_Users"].append(registeredusers)
                    column9["States"].append(state)
                    column9["Years"].append(year)
                    column9["Quarter"].append(int(file.strip(".json")))

# %%
top_user=pd.DataFrame(column9)

top_user["States"]=top_user["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar Island')
top_user["States"]=top_user["States"].str.replace('-',' ')
top_user["States"]=top_user["States"].str.title()
top_user["States"]=top_user["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu ')

# %%
top_user
# Out:
#                         States Years  Quarter Pincodes  Registered_Users
# 0     Andaman & Nicobar Island  2018        1   744103              1608
# 1     Andaman & Nicobar Island  2018        1   744101              1108
# 2     Andaman & Nicobar Island  2018        1   744105              1075
# 3     Andaman & Nicobar Island  2018        1   744102              1006
# 4     Andaman & Nicobar Island  2018        1   744104               272
# ...                        ...   ...      ...      ...               ...
# 8206               West Bengal  2023        3   700015            122316
# 8207               West Bengal  2023        3   742304            119245
# 8208               West Bengal  2023        3   721101            118798
# 8209               West Bengal  2023        3   700150            114987
# 8210               West Bengal  2023        3   734006            113991
#
# [8211 rows x 5 columns]

# %%
mydb = psycopg2.connect(host="localhost",
                        user='postgres',
                        port="5432",
                        database="phonepe_data",
                        password="Danv2001")

cursor= mydb.cursor()

create_query_1= '''CREATE TABLE if not exists aggregated_insurance(States varchar(255),
                                                    Years int,
                                                    Quarter int,
                                                    Transaction_type varchar(255),
                                                    Transaction_count bigint,
                                                    Transaction_amount bigint)'''

cursor.execute(create_query_1)
mydb.commit()


insert_query_1='''INSERT INTO aggregated_insurance(States, 
                                                    Years,
                                                    Quarter,
                                                    Transaction_type,
                                                    Transaction_count,
                                                    Transaction_amount)


                                                    values(%s,%s,%s,%s,%s,%s)'''
                                                    
                                                    
data = aggre_insurance.values.tolist()

cursor.executemany(insert_query_1, data)

mydb.commit()

# %%
mydb = psycopg2.connect(host="localhost",
                        user='postgres',
                        port="5432",
                        database="phonepe_data",
                        password="Danv2001")

cursor= mydb.cursor()

create_query_2= '''CREATE TABLE if not exists aggregated_transaction(States varchar(255),
                                                    Years int,
                                                    Quarter int,
                                                    Transaction_type varchar(255),
                                                    Transaction_count bigint,
                                                    Transaction_amount bigint)'''

cursor.execute(create_query_2)
mydb.commit()


insert_query_2='''INSERT INTO aggregated_transaction(States, 
                                                    Years,
                                                    Quarter,
                                                    Transaction_type,
                                                    Transaction_count,
                                                    Transaction_amount)


                                                    values(%s,%s,%s,%s,%s,%s)'''
                                                    
                                                    
data = aggre_transaction.values.tolist()

cursor.executemany(insert_query_2, data)

mydb.commit()

# %%
mydb = psycopg2.connect(host="localhost",
                        user='postgres',
                        port="5432",
                        database="phonepe_data",
                        password="Danv2001")

cursor= mydb.cursor()

create_query_3= '''CREATE TABLE if not exists aggregated_user(States varchar(255),
                                                    Years int,
                                                    Quarter int,
                                                    Brands varchar(255),
                                                    Transaction_count bigint,
                                                    Percentage float)'''

cursor.execute(create_query_3)
mydb.commit()


insert_query_3='''INSERT INTO aggregated_user(States, 
                                                    Years,
                                                    Quarter,
                                                    Brands,
                                                    Transaction_count,
                                                    Percentage)


                                                    values(%s,%s,%s,%s,%s,%s)'''
                                                    
                                                    
data = agg_user.values.tolist()

cursor.executemany(insert_query_3, data)

mydb.commit()

# %%
mydb = psycopg2.connect(host="localhost",
                        user='postgres',
                        port="5432",
                        database="phonepe_data",
                        password="Danv2001")

cursor= mydb.cursor()

create_query_4= '''CREATE TABLE if not exists map_insurance(States varchar(255),
                                                    Years int,
                                                    Quarter int,
                                                    District varchar(255),
                                                    Transaction_Count bigint,
                                                    Transaction_Amount bigint)'''
                                                    

cursor.execute(create_query_4)
mydb.commit()


insert_query_4='''INSERT INTO map_insurance(States, 
                                                    Years,
                                                    Quarter,
                                                    District,
                                                    Transaction_Count,
                                                    Transaction_Amount)


                                                    values(%s,%s,%s,%s,%s,%s)'''
                                                    
                                                    
data = map_insurance.values.tolist()

cursor.executemany(insert_query_4, data)

mydb.commit()

# %%
mydb = psycopg2.connect(host="localhost",
                        user='postgres',
                        port="5432",
                        database="phonepe_data",
                        password="Danv2001")

cursor= mydb.cursor()

create_query_5= '''CREATE TABLE if not exists map_transaction(States varchar(255),
                                                    Years int,
                                                    Quarter int,
                                                    District varchar(255),
                                                    Transaction_Count bigint,
                                                    Transaction_Amount bigint)'''
                                                    

cursor.execute(create_query_5)
mydb.commit()


insert_query_5='''INSERT INTO map_transaction(States, 
                                                    Years,
                                                    Quarter,
                                                    District,
                                                    Transaction_Count,
                                                    Transaction_Amount)


                                                    values(%s,%s,%s,%s,%s,%s)'''
                                                    
                                                    
data = map_transaction.values.tolist()

cursor.executemany(insert_query_5, data)

mydb.commit()

# %%
mydb = psycopg2.connect(host="localhost",
                        user='postgres',
                        port="5432",
                        database="phonepe_data",
                        password="Danv2001")

cursor= mydb.cursor()

create_query_6= '''CREATE TABLE if not exists map_user(States varchar(255),
                                                    Years int,
                                                    Quarter int,
                                                    District varchar(255),
                                                    Registered_Users bigint,
                                                    App_Opens bigint)'''
                                                    

cursor.execute(create_query_6)
mydb.commit()


insert_query_6='''INSERT INTO map_user(States, 
                                                    Years,
                                                    Quarter,
                                                    District,
                                                    Registered_Users,
                                                     App_Opens)


                                                    values(%s,%s,%s,%s,%s,%s)'''
                                                    
                                                    
data = map_user.values.tolist()

cursor.executemany(insert_query_6, data)

mydb.commit()

# %%
mydb = psycopg2.connect(host="localhost",
                        user='postgres',
                        port="5432",
                        database="phonepe_data",
                        password="Danv2001")

cursor= mydb.cursor()

create_query_7= '''CREATE TABLE if not exists top_insurance(States varchar(255),
                                                    Years int,
                                                    Quarter int,
                                                    Pincodes bigint,
                                                    Transaction_Count bigint,
                                                    Transaction_Amount bigint)'''
                                                    

cursor.execute(create_query_7)
mydb.commit()


insert_query_7='''INSERT INTO top_insurance(States, 
                                                    Years,
                                                    Quarter,
                                                    Pincodes,
                                                    Transaction_Count,
                                                    Transaction_Amount)


                                                    values(%s,%s,%s,%s,%s,%s)'''
                                                    
                                                    
data = top_insurance.values.tolist()

cursor.executemany(insert_query_7, data)

mydb.commit()

# %%
mydb = psycopg2.connect(host="localhost",
                        user='postgres',
                        port="5432",
                        database="phonepe_data",
                        password="Danv2001")

cursor= mydb.cursor()

create_query_8= '''CREATE TABLE if not exists top_transaction(States varchar(255),
                                                    Years int,
                                                    Quarter int,
                                                    Entity_Name varchar(200),
                                                    Transaction_Count bigint,
                                                    Transaction_Amount bigint)'''
                                                    

cursor.execute(create_query_8)
mydb.commit()


insert_query_8='''INSERT INTO top_transaction(States, 
                                                    Years,
                                                    Quarter,
                                                    Entity_Name,
                                                    Transaction_Count,
                                                    Transaction_Amount)


                                                    values(%s,%s,%s,%s,%s,%s)'''
                                                    
                                                    
data = top_transaction.values.tolist()

cursor.executemany(insert_query_8, data)

mydb.commit()

# %%
mydb = psycopg2.connect(host="localhost",
                        user='postgres',
                        port="5432",
                        database="phonepe_data",
                        password="Danv2001")

cursor= mydb.cursor()

create_query_9= '''CREATE TABLE if not exists top_user(States varchar(255),
                                                    Years int,
                                                    Quarter int,
                                                    Pincodes bigint,
                                                    Registered_Users bigint)'''
                                                    

cursor.execute(create_query_9)
mydb.commit()


insert_query_9='''INSERT INTO top_user(States, 
                                                    Years,
                                                    Quarter,
                                                    Pincodes,
                                                    Registered_Users)


                                                    values(%s,%s,%s,%s,%s)'''
                                                    
                                                    
data = top_user.values.tolist()

cursor.executemany(insert_query_9, data)

mydb.commit()
